# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, label_ranking_average_precision_score, label_ranking_loss, coverage_error 

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

#ECG images database available on "https://data.mendeley.com/datasets/gwbz3fsgp8/2"
print(os.listdir("C:/Users/SplendidUnivers/Desktop/ECGimages"))
# Out:
# Using TensorFlow backend.
# ['ECG Images of Myocardial Infarction Patients (240x12=2880)', 'ECG Images of Patient that have abnormal heartbeat (233x12=2796)', 'ECG Images of Patient that have History of MI (172x12=2064)', 'Normal Person ECG Images (284x12=3408)']

# %%
#CNN model

#Classification
classifier = Sequential()

#Adding 1st Convolution and Pooling Layer
classifier.add(Conv2D(32,kernel_size=(3,3),input_shape = (64, 64, 3), activation = 'elu'))
classifier.add(BatchNormalization())
classifier.add(MaxPool2D(pool_size=(2,2)))

#Adding 2nd Convolution and Pooling Layer
classifier.add(Conv2D(32,kernel_size=(3,3),activation = 'elu'))
classifier.add(BatchNormalization())
classifier.add(MaxPool2D(pool_size=(2,2)))

#Adding 3rd Convolution and Pooling Layer
classifier.add(Conv2D(32,kernel_size=(3,3), activation = 'elu'))
classifier.add(BatchNormalization())
classifier.add(MaxPool2D(pool_size=(2,2)))

#Adding 4th Convolution and Pooling Layer
classifier.add(Conv2D(32,kernel_size=(3,3), activation = 'elu'))
classifier.add(BatchNormalization())
classifier.add(MaxPool2D(pool_size=(2,2)))


#Flattening
classifier.add(Flatten())

classifier.add(Dense(units=128,activation='elu'))
classifier.add(BatchNormalization())
classifier.add(Dense(units = 1, activation = 'sigmoid'))

classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])


#split data train and validation
train_datagen = ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
train_data = train_datagen.flow_from_directory('C:/Users/SplendidUnivers/Desktop/data2/',
                                                     target_size=(64,64),
                                                     batch_size=32,
                                                     class_mode = 'binary')
val_data = val_datagen.flow_from_directory('C:/Users/SplendidUnivers/Desktop/data2/',
                                                        target_size=(64,64),
                                                        batch_size=32,
                                                        class_mode = 'binary')


#accuracies calculation
accuracies = classifier.fit_generator(train_data,
                         steps_per_epoch = 100,
                         epochs = 30,
                         validation_data = val_data,
                         validation_steps = 50)

#show accuracy
acc = pd.DataFrame.from_dict(accuracies.history)
acc = pd.concat([pd.Series(range(0,30),name='epochs'),acc],axis=1)
acc.head()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0805 20:06:27.213015 12848 deprecation_wrapper.py:119] From C:\Users\SplendidUnivers\Miniconda3\envs\test\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0805 20:06:27.730430 12848 deprecation.py:323] From C:\Users\SplendidUnivers\Miniconda3\envs\test\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Found 243 images belonging to 2 classes.
# Found 243 images belonging to 2 classes.
# W0805 20:06:30.144128 12848 deprecation_wrapper.py:119] From C:\Users\SplendidUnivers\Miniconda3\envs\test\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# Epoch 1/30
# 100/100 [==============================] - 33s 332ms/step - loss: 0.5482 - accuracy: 0.7318 - val_loss: 0.5051 - val_accuracy: 0.8141
# Epoch 2/30
# 100/100 [==============================] - 27s 268ms/step - loss: 0.3556 - accuracy: 0.8555 - val_loss: 0.4453 - val_accuracy: 0.8154
# Epoch 3/30
# 100/100 [==============================] - 27s 266ms/step - loss: 0.2896 - accuracy: 0.8804 - val_loss: 0.4027 - val_accuracy: 0.8535
# Epoch 4/30
# 100/100 [==============================] - 27s 272ms/step - loss: 0.2522 - accuracy: 0.8934 - val_loss: 0.3645 - val_accuracy: 0.9059
# Epoch 5/30
# 100/100 [==============================] - 26s 259ms/step - loss: 0.2291 - accuracy: 0.9001 - val_loss: 0.1312 - val_accuracy: 0.9310
# Epoch 6/30
# 100/100 [==============================] - 27s 271ms/step - loss: 0.2162 - accuracy: 0.9073 - val_loss: 0.2028 - val_accuracy: 0.9284
# Epoch 7/30
# 100/100 [==============================] - 27s 273ms/step - loss: 0.1988 - accuracy: 0.9129 - val_loss: 0.1107 - val_accuracy: 0.9205
# Epoch 8/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.1946 - accuracy: 0.9202 - val_loss: 0.1341 - val_accuracy: 0.9205
# Epoch 9/30
# 100/100 [==============================] - 27s 266ms/step - loss: 0.1820 - accuracy: 0.9169 - val_loss: 0.0803 - val_accuracy: 0.9343
# Epoch 10/30
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1851 - accuracy: 0.9169 - val_loss: 0.1424 - val_accuracy: 0.9133
# Epoch 11/30
# 100/100 [==============================] - 25s 253ms/step - loss: 0.1752 - accuracy: 0.9198 - val_loss: 0.1014 - val_accuracy: 0.9218
# Epoch 12/30
# 100/100 [==============================] - 25s 253ms/step - loss: 0.1836 - accuracy: 0.9218 - val_loss: 0.0713 - val_accuracy: 0.9271
# Epoch 13/30
# 100/100 [==============================] - 25s 250ms/step - loss: 0.1653 - accuracy: 0.9238 - val_loss: 0.1053 - val_accuracy: 0.9238
# Epoch 14/30
# 100/100 [==============================] - 25s 248ms/step - loss: 0.1576 - accuracy: 0.9238 - val_loss: 0.0692 - val_accuracy: 0.9350
# Epoch 15/30
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1614 - accuracy: 0.9235 - val_loss: 0.1306 - val_accuracy: 0.9264
# Epoch 16/30
# 100/100 [==============================] - 26s 259ms/step - loss: 0.1612 - accuracy: 0.9267 - val_loss: 0.1928 - val_accuracy: 0.9185
# Epoch 17/30
# 100/100 [==============================] - 24s 240ms/step - loss: 0.1569 - accuracy: 0.9287 - val_loss: 0.1969 - val_accuracy: 0.9225
# Epoch 18/30
# 100/100 [==============================] - 24s 238ms/step - loss: 0.1474 - accuracy: 0.9304 - val_loss: 0.1364 - val_accuracy: 0.9317
# Epoch 19/30
# 100/100 [==============================] - 25s 245ms/step - loss: 0.1556 - accuracy: 0.9215 - val_loss: 0.0689 - val_accuracy: 0.9389
# Epoch 20/30
# 100/100 [==============================] - 25s 254ms/step - loss: 0.1489 - accuracy: 0.9271 - val_loss: 0.1318 - val_accuracy: 0.9132
# Epoch 21/30
# 100/100 [==============================] - 25s 251ms/step - loss: 0.1488 - accuracy: 0.9248 - val_loss: 0.0768 - val_accuracy: 0.9343
# Epoch 22/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.1475 - accuracy: 0.9284 - val_loss: 0.1455 - val_accuracy: 0.9225
# Epoch 23/30
# 100/100 [==============================] - 25s 249ms/step - loss: 0.1528 - accuracy: 0.9287 - val_loss: 0.0255 - val_accuracy: 0.9317
# Epoch 24/30
# 100/100 [==============================] - 25s 254ms/step - loss: 0.1452 - accuracy: 0.9271 - val_loss: 0.1426 - val_accuracy: 0.9311
# Epoch 25/30
# 100/100 [==============================] - 25s 254ms/step - loss: 0.1466 - accuracy: 0.9291 - val_loss: 0.2004 - val_accuracy: 0.9343
# Epoch 26/30
# 100/100 [==============================] - 27s 269ms/step - loss: 0.1400 - accuracy: 0.9323 - val_loss: 0.1522 - val_accuracy: 0.9382
# Epoch 27/30
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1474 - accuracy: 0.9287 - val_loss: 0.0451 - val_accuracy: 0.9382
# Epoch 28/30
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1419 - accuracy: 0.9281 - val_loss: 0.1152 - val_accuracy: 0.9370
# Epoch 29/30
# 100/100 [==============================] - 27s 269ms/step - loss: 0.1388 - accuracy: 0.9238 - val_loss: 0.0141 - val_accuracy: 0.9356
# Epoch 30/30
# 100/100 [==============================] - 26s 262ms/step - loss: 0.1363 - accuracy: 0.9294 - val_loss: 0.1738 - val_accuracy: 0.9376
#    epochs  val_loss  val_accuracy      loss  accuracy
# 0       0  0.505146      0.814060  0.547409  0.731772
# 1       1  0.445276      0.815374  0.355304  0.855453
# 2       2  0.402691      0.853482  0.287293  0.880421
# 3       3  0.364454      0.905898  0.251232  0.893435
# 4       4  0.131245      0.931012  0.229205  0.900131
